# %% [markdown]
# ##  Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ## Import the dataset and assign it to a variable called gamo.

# %%
gamo = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv')
gamo.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
gamo.applymap(function, na_action= 'ignore')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7232\2224658810.py in <module>
# ----> 1 gamo.applymap(function, na_action= 'ignore')
#
# NameError: name 'function' is not defined

# %% [markdown]
# ## Select only the Name column.

# %%
gamo.Name
# Out:
# 0                           Wii Sports
# 1                    Super Mario Bros.
# 2                       Mario Kart Wii
# 3                    Wii Sports Resort
# 4             Pokemon Red/Pokemon Blue
#                      ...
# 16714    Samurai Warriors: Sanada Maru
# 16715                 LMA Manager 2007
# 16716          Haitaka no Psychedelica
# 16717                 Spirits & Spells
# 16718              Winning Post 8 2016
# Name: Name, Length: 16719, dtype: object

# %% [markdown]
# ## What is the number of columns in the dataset?

# %%
gamo.shape[1]
# Out:
# 16

# %% [markdown]
# ## Set the 'Name' column as the index of the dataframe

# %%
gamo.set_index('Name', inplace=True)

# %% [markdown]
# ## View only the columns  Year_of_Release, Global_Sales and Rating and assign them to a dataframe called discipline¶

# %%
# filter only giving the column names

discipline = gamo[['Year_of_Release', 'Global_Sales', 'Rating']]
discipline
# Out:
#                                Year_of_Release  Global_Sales Rating
# Name
# Wii Sports                              2006.0         82.53      E
# Super Mario Bros.                       1985.0         40.24    NaN
# Mario Kart Wii                          2008.0         35.52      E
# Wii Sports Resort                       2009.0         32.77      E
# Pokemon Red/Pokemon Blue                1996.0         31.37    NaN
# ...                                        ...           ...    ...
# Samurai Warriors: Sanada Maru           2016.0          0.01    NaN
# LMA Manager 2007                        2006.0          0.01    NaN
# Haitaka no Psychedelica                 2016.0          0.01    NaN
# Spirits & Spells                        2003.0          0.01    NaN
# Winning Post 8 2016                     2016.0          0.01    NaN
#
# [16719 rows x 3 columns]

# %% [markdown]
# ## Sort the games by Year_of_Release then to Global_Sales

# %%
discipline.sort_values(['Year_of_Release', 'Global_Sales'], ascending = False)
# Out:
#                                                   Year_of_Release  \
# Name
# Imagine: Makeup Artist                                     2020.0
# Phantasy Star Online 2 Episode 4: Deluxe Package           2017.0
# Phantasy Star Online 2 Episode 4: Deluxe Package           2017.0
# Brothers Conflict: Precious Baby                           2017.0
# FIFA 17                                                    2016.0
# ...                                                           ...
# PDC World Championship Darts 2008                             NaN
# Freaky Flyers                                                 NaN
# Inversion                                                     NaN
# Hakuouki: Shinsengumi Kitan                                   NaN
# Virtua Quest                                                  NaN
#
#                                                   Global_Sales Rating
# Name
# Imagine: Makeup Artist                                    0.29      E
# ...

# %% [markdown]
# ## Calculate the mean Global_Sales given per game

# %%
round(discipline['Global_Sales'].mean())
# Out:
# 1

# %% [markdown]
# ## Filter teams that made before 2010

# %%
gamo[gamo.Year_of_Release > 2010]
# Out:
#                                Platform  Year_of_Release         Genre  \
# Name
# Grand Theft Auto V                  PS3           2013.0        Action
# Grand Theft Auto V                 X360           2013.0        Action
# Call of Duty: Modern Warfare 3     X360           2011.0       Shooter
# Call of Duty: Black Ops 3           PS4           2015.0       Shooter
# Pokemon X/Pokemon Y                 3DS           2013.0  Role-Playing
# ...                                 ...              ...           ...
# Strawberry Nauts                    PSV           2016.0     Adventure
# Aiyoku no Eustia                    PSV           2014.0          Misc
# Samurai Warriors: Sanada Maru       PS3           2016.0        Action
# Haitaka no Psychedelica             PSV           2016.0     Adventure
# Winning Post 8 2016                 PSV           2016.0    Simulation
#
#                                            Publisher  NA_Sales  EU_Sales  \
# Name
# ...

# %% [markdown]
# ## Select the first 7 columns

# %%
# use .iloc to slices via the position of the passed integers
# : means all, 0:7 means from 0 to 7

gamo.iloc[: , 0:7]
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
#           Publisher  NA_Sales  EU_Sales
# ...

# %% [markdown]
# ## Select all columns except the last 3.

# %%
gamo.iloc[: , :-3]
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# ##  Present only the Genre for Pokemon X/Pokemon Y, Aiyoku no Eustia and Winning Post 8 2016.

# %%
# .loc is another way to slice, using the labels of the columns and indexes
gamo.loc[gamo.Name.isin( ['Pokemon X/Pokemon Y', 'Aiyoku no Eustia', 'Winning Post 8 2016']), ['Name', 'Genre']]
# Out:
#                       Name         Genre
# 33     Pokemon X/Pokemon Y  Role-Playing
# 15601  Winning Post 8 2016    Simulation
# 16711     Aiyoku no Eustia          Misc
# 16718  Winning Post 8 2016    Simulation
